# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\pushp\Downloads\E-commerce Dataset.csv")
df
# Out:
#        Order_Date      Time  Aging  Customer_Id  Gender Device_Type  \
# 0      02-01-2018  10:56:33    8.0        37077  Female         Web
# 1      24-07-2018  20:41:37    2.0        59173  Female         Web
# 2      08-11-2018  08:38:49    8.0        41066  Female         Web
# 3      18-04-2018  19:28:06    7.0        50741  Female         Web
# 4      13-08-2018  21:18:39    9.0        53639  Female         Web
# ...           ...       ...    ...          ...     ...         ...
# 51285  28-02-2018  22:59:50    6.0        78489  Female      Mobile
# 51286  28-02-2018  13:19:25    2.0        91941  Female      Mobile
# 51287  28-02-2018  10:25:07    6.0        63313    Male         Web
# 51288  28-02-2018  10:50:08    7.0        86485    Male         Web
# 51289  28-02-2018  11:09:40    5.0        81129    Male         Web
#
#       Customer_Login_type    Product_Category            Product  Sales  \
# 0                  Member  Auto & Accessories  Car Media Players  140.0
# ...

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Visulization

# %% [markdown]
# #### Sales by product category

# %%
import matplotlib.pyplot as plt

# Calculate total sales for each category
category_sales = df.groupby("Product_Category")["Sales"].sum().sort_values(ascending=False)

# Create bar chart
plt.figure(figsize=(10,6))
category_sales.plot(kind="bar", color="purple", edgecolor="black")

# Add title and labels
plt.title("Total Sales by Product Category", fontsize=14)
plt.xlabel("Product Category", fontsize=12)
plt.ylabel("Total Sales", fontsize=12)

# Rotate x-axis labels
plt.xticks(rotation=360, ha="right")

plt.show()

# %% [markdown]
# #### Total Profit by product Category

# %%
# calculate total proit by each category
total_profit_by_category=df.groupby('Product_Category')['Profit'].sum().sort_values(ascending=True)

# Create bar chart
plt.figure(figsize=(10,6))
total_profit_by_category.plot(kind="bar",color="Purple",edgecolor='Black')

# Add title and labels
plt.title("Total profit by product category",fontsize=14)
plt.xlabel("Total Product_category",fontsize=12)
plt.ylabel("Total Profit",fontsize=12)

# Rotate x_axis labels
plt.xticks(rotation=360,ha='right')
plt.show()

# %% [markdown]
# ### Sales Vs Profit

# %%
plt.figure(figsize=(10,10))
plt.scatter(df['Sales'],df['Profit'],color="Purple")
plt.title("Sales Vs Profit")
plt.xlabel("Sales")
plt.ylabel("Profit")
plt.show()

# %% [markdown]
# ### Histogram-Distribution of sales

# %%
plt.figure(figsize=(8,7))

# Create histogram
plt.hist(df["Sales"],color="Purple",edgecolor="black",bins=20)

# Create labels
plt.title("Distribution of sales",fontsize=14)
plt.xlabel("Sales")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### Pie Chart - Payment method

# %%
plt.figure(figsize=(7,7))
payment=df["Payment_method"].value_counts()
plt.pie(payment,labels=payment.index,autopct="%1.1f%%",
        startangle=90)
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(8,6))

sns.heatmap(df.select_dtypes(include="number").corr(),
            annot=True,
            cmap="coolwarm")

plt.title("Correlation Heatmap")

plt.show()

# %%
df["Order_Date"] = pd.to_datetime(df["Order_Date"], dayfirst=True)

sales = df.groupby("Order_Date")["Sales"].sum()

plt.figure(figsize=(12,5))

sales.plot()

plt.title("Sales Trend")
plt.xlabel("Date")
plt.ylabel("Sales")

plt.show()
